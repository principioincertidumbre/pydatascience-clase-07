# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_canciones = pd.read_csv("universal_top_spotify_songs.csv")

# %%
df_canciones['date'] = pd.to_datetime(df_canciones["snapshot_date"])

# %%
df_canciones.head()
# Out:
#                spotify_id                  name            artists  \
# 0  7tI8dRuH2Yc6RuoTjxo4dU                   Who              Jimin
# 1  6dOtVTDdiauQNBQEDOtlAB    BIRDS OF A FEATHER      Billie Eilish
# 2  2qSkIjg1o9h3YT9RAgYN75              Espresso  Sabrina Carpenter
# 3  5N3hjp1WNayUPZrA8kJmJP  Please Please Please  Sabrina Carpenter
# 4  6AI3ezQ4o3HUoP6Dhudph3           Not Like Us     Kendrick Lamar
#
#    daily_rank  daily_movement  weekly_movement country snapshot_date  \
# 0           1               0               49     NaN    2024-07-26
# 1           2               0               -1     NaN    2024-07-26
# 2           3               0               -1     NaN    2024-07-26
# 3           4               0               -1     NaN    2024-07-26
# 4           5               0               -1     NaN    2024-07-26
#
#    popularity  is_explicit  ...  loudness mode speechiness  acousticness  \
# ...

# %% [markdown]
# # Descripción de columnas
#
# **spotify_id** ID de la canción en Spotify
#
# **name** Nombre de la canción

# %%
df_canciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018853 entries, 0 to 1018852
# Data columns (total 25 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   spotify_id          1018853 non-null  object
#  1   name                1018826 non-null  object
#  2   artists             1018826 non-null  object
#  3   daily_rank          1018853 non-null  int64
#  4   daily_movement      1018853 non-null  int64
#  5   weekly_movement     1018853 non-null  int64
#  6   country             1005046 non-null  object
#  7   snapshot_date       1018853 non-null  object
#  8   popularity          1018853 non-null  int64
#  9   is_explicit         1018853 non-null  bool
#  10  duration_ms         1018853 non-null  int64
#  11  album_name          1018334 non-null  object
#  12  album_release_date  1018473 non-null  object
#  13  danceability        1018853 non-null  float64
#  14  energy              1018853 non-null  float64
# ...

# %%
df_canciones.isna().sum()
# Out:
# spotify_id                0
# name                     27
# artists                  27
# daily_rank                0
# daily_movement            0
# weekly_movement           0
# country               13807
# snapshot_date             0
# popularity                0
# is_explicit               0
# duration_ms               0
# album_name              519
# album_release_date      380
# danceability              0
# energy                    0
# key                       0
# loudness                  0
# mode                      0
# speechiness               0
# acousticness              0
# instrumentalness          0
# liveness                  0
# valence                   0
# tempo                     0
# time_signature            0
# dtype: int64

# %%
fechas = pd.to_datetime(df_canciones["snapshot_date"])
fechas
# Out:
# 0         2024-07-26
# 1         2024-07-26
# 2         2024-07-26
# 3         2024-07-26
# 4         2024-07-26
#              ...
# 1018848   2023-10-18
# 1018849   2023-10-18
# 1018850   2023-10-18
# 1018851   2023-10-18
# 1018852   2023-10-18
# Name: snapshot_date, Length: 1018853, dtype: datetime64[ns]

# %%
fechas.max() - fechas.min()
# Out:
# Timedelta('282 days 00:00:00')

# %%
fechas.value_counts()
# Out:
# snapshot_date
# 2024-03-16    3942
# 2023-11-20    3866
# 2024-03-18    3836
# 2024-03-14    3769
# 2023-10-27    3766
#               ...
# 2024-04-20    3150
# 2024-04-24    2500
# 2024-04-23    2100
# 2024-04-21    1900
# 2024-04-22    1850
# Name: count, Length: 281, dtype: int64

# %%
df_chile = df_canciones[df_canciones['country'] == 'CL']

# %%
df_chile.head(10)
# Out:
#                   spotify_id                          name  \
# 3050  21hsqOOUfdSjHi3SVz8oyv              No Ponga Excusas
# 3051  5PCGEfALcpGtURIuTqvX0R                     PELIGROSA
# 3052  7tI8dRuH2Yc6RuoTjxo4dU                           Who
# 3053  4yyCGGdTVaYG17vhsrUPoL                  APAGA EL CEL
# 3054  6WatFBLVB0x077xWeoVc2k  Si Antes Te Hubiera Conocido
# 3055  5Uptvz6j1sjDKxidAcnH2L              SI NO ES CONTIGO
# 3056  2II1TSrlhRrtz2hmzpXROT                  Mi Automóvil
# 3057  2btNsI4OvcVl7SAHQQDHFB                        Mirame
# 3058  6XjDF6nds4DE2BBbagZol6                     Gata Only
# 3059  1pymWRCuZfCd0zdiBJo0Hj             REAL GANGSTA LOVE
#
#                        artists  daily_rank  daily_movement  weekly_movement  \
# 3050                   Cris Mj           1               0                0
# 3051                FloyyMenor           2               2                7
# 3052                     Jimin           3              -1               47
# ...

# %%
df_canciones.corr(numeric_only=True)
# Out:
#                   daily_rank  daily_movement  weekly_movement  popularity  \
# daily_rank          1.000000       -0.143130        -0.268814   -0.105964
# daily_movement     -0.143130        1.000000         0.307404   -0.191951
# weekly_movement    -0.268814        0.307404         1.000000   -0.185345
# popularity         -0.105964       -0.191951        -0.185345    1.000000
# is_explicit        -0.032105       -0.005532        -0.006032    0.115957
# duration_ms         0.042916       -0.000412        -0.001731    0.002739
# danceability       -0.069418       -0.011074        -0.014577   -0.015566
# energy             -0.033737       -0.006387        -0.003842    0.022958
# key                -0.033460       -0.005151        -0.004759    0.014357
# loudness           -0.046249       -0.021632        -0.021336    0.140756
# mode               -0.015259        0.007581         0.012265    0.106939
# speechiness         0.009214        0.002716         0.010292   -0.157240
# ...
